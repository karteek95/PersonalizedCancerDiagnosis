# %% [markdown]
# * <b>Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\karteek\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Reading the data
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %%
# Reading the text file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# ### Pre processing of text

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', str(total_text))
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', str(total_text))
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    nlp_preprocessing(row['TEXT'], index, 'TEXT')
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# Time took for preprocessing the text : 237.66050216392054 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %% [markdown]
# <h3>Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4> Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4> Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = ['r', 'g', 'b', 'k', 'y', 'm', 'c']
train_class_distribution.plot(kind='bar', color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = ['r', 'g', 'b', 'k', 'y', 'm', 'c']
test_class_distribution.plot(kind='bar', color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = ['r', 'g', 'b', 'k', 'y', 'm', 'c']
cv_class_distribution.plot(kind='bar', color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2> Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.4720996925367356
# Log loss on Test Data using Random Model 2.4643471996279596
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2> Vectorizing</h2>

# %%
# Gene Feature
gene_vectorizer = TfidfVectorizer(max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
#Variation Feature
variation_vectorizer = TfidfVectorizer(max_features=1000)
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
#text
text_vectorizer = TfidfVectorizer(min_df=3,max_features=1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)
# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_tfidf = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_tfidf = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_tfidf = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("TF IDF features :")
print("(number of data points * number of features) in train data = ", train_x_tfidf.shape)
print("(number of data points * number of features) in test data = ", test_x_tfidf.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_tfidf.shape)
# Out:
# TF IDF features :
# (number of data points * number of features) in train data =  (2124, 2235)
# (number of data points * number of features) in test data =  (665, 2235)
# (number of data points * number of features) in cross validation data = (532, 2235)

# %% [markdown]
# <h2>1. Base Line Model</h2>

# %% [markdown]
# <h3>1.1. Naive Bayes</h3>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)


predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1554669118280017
# for alpha = 0.0001
# Log Loss : 1.1550370969240282
# for alpha = 0.001
# Log Loss : 1.1531824205470795
# for alpha = 0.1
# Log Loss : 1.1604453828373094
# for alpha = 1
# Log Loss : 1.2128333529928417
# for alpha = 10
# Log Loss : 1.4164740851115496
# for alpha = 100
# Log Loss : 1.4281606978378962
# for alpha = 1000
# Log Loss : 1.4190328256084244
# For values of best alpha =  0.001 The train log loss is: 0.7645267517869868
# For values of best alpha =  0.001 The cross validation log loss is: 1.1531824205470795
# For values of best alpha =  0.001 The test log loss is: 1.1809491807936612

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_tfidf)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_tfidf.toarray()))
# Out:
# Log Loss : 1.1531824205470795
# Number of missclassified point : 0.3609022556390977
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>1.1.3. Feature Importance, Correctly classified point</h4>

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(min_df=3,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
test_point_index = 8
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1185 0.0511 0.015  0.6628 0.038  0.0358 0.0723 0.0033 0.0033]]
# Actual Class : 4
# --------------------------------------------------
# 9 Text feature [activity] present in test data point [True]
# 10 Text feature [protein] present in test data point [True]
# 13 Text feature [proteins] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 16 Text feature [experiments] present in test data point [True]
# 17 Text feature [results] present in test data point [True]
# 18 Text feature [acid] present in test data point [True]
# 26 Text feature [catalytic] present in test data point [True]
# 27 Text feature [also] present in test data point [True]
# 29 Text feature [amino] present in test data point [True]
# 30 Text feature [shown] present in test data point [True]
# 33 Text feature [described] present in test data point [True]
# 34 Text feature [may] present in test data point [True]
# 35 Text feature [mutations] present in test data point [True]
# 36 Text feature [either] present in test data point [True]
# 37 Text feature [whether] present in test data point [True]
# 38 Text feature [two] present in test data point [True]
# 39 Text feature [determined] present in test data point [True]
# 41 Text feature [ability] present in test data point [True]
# 42 Text feature [vitro] present in test data point [True]
# 43 Text feature [vivo] present in test data point [True]
# 45 Text feature [although] present in test data point [True]
# 46 Text feature [three] present in test data point [True]
# 48 Text feature [levels] present in test data point [True]
# 52 Text feature [therefore] present in test data point [True]
# 53 Text feature [suggest] present in test data point [True]
# 54 Text feature [containing] present in test data point [True]
# 56 Text feature [thus] present in test data point [True]
# 58 Text feature [reduced] present in test data point [True]
# 62 Text feature [previously] present in test data point [True]
# 64 Text feature [generated] present in test data point [True]
# 65 Text feature [discussion] present in test data point [True]
# 68 Text feature [analysis] present in test data point [True]
# 69 Text feature [show] present in test data point [True]
# 70 Text feature [lower] present in test data point [True]
# 71 Text feature [cells] present in test data point [True]
# 72 Text feature [several] present in test data point [True]
# 74 Text feature [suggesting] present in test data point [True]
# 76 Text feature [effects] present in test data point [True]
# 77 Text feature [reported] present in test data point [True]
# 80 Text feature [introduction] present in test data point [True]
# 81 Text feature [however] present in test data point [True]
# 82 Text feature [expressed] present in test data point [True]
# 83 Text feature [using] present in test data point [True]
# 84 Text feature [analyzed] present in test data point [True]
# 85 Text feature [similar] present in test data point [True]
# 87 Text feature [found] present in test data point [True]
# 88 Text feature [caused] present in test data point [True]
# 89 Text feature [effect] present in test data point [True]
# 91 Text feature [expression] present in test data point [True]
# 92 Text feature [tagged] present in test data point [True]
# 93 Text feature [one] present in test data point [True]
# 94 Text feature [buffer] present in test data point [True]
# 95 Text feature [control] present in test data point [True]
# 96 Text feature [addition] present in test data point [True]
# 97 Text feature [assay] present in test data point [True]
# 98 Text feature [mutant] present in test data point [True]
# 99 Text feature [bind] present in test data point [True]
# Out of the top  100  features  58 are present in query point

# %% [markdown]
# <h4>1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.5945 0.0673 0.0165 0.1516 0.0418 0.0398 0.0812 0.0036 0.0037]]
# Actual Class : 4
# --------------------------------------------------
# 9 Text feature [one] present in test data point [True]
# 10 Text feature [protein] present in test data point [True]
# 11 Text feature [two] present in test data point [True]
# 12 Text feature [type] present in test data point [True]
# 13 Text feature [results] present in test data point [True]
# 14 Text feature [also] present in test data point [True]
# 15 Text feature [dna] present in test data point [True]
# 16 Text feature [possible] present in test data point [True]
# 17 Text feature [function] present in test data point [True]
# 18 Text feature [therefore] present in test data point [True]
# 20 Text feature [role] present in test data point [True]
# 21 Text feature [however] present in test data point [True]
# 22 Text feature [either] present in test data point [True]
# 23 Text feature [loss] present in test data point [True]
# 24 Text feature [using] present in test data point [True]
# 25 Text feature [wild] present in test data point [True]
# 26 Text feature [least] present in test data point [True]
# 27 Text feature [specific] present in test data point [True]
# 33 Text feature [three] present in test data point [True]
# 36 Text feature [25] present in test data point [True]
# 38 Text feature [containing] present in test data point [True]
# 39 Text feature [analysis] present in test data point [True]
# 43 Text feature [binding] present in test data point [True]
# 45 Text feature [30] present in test data point [True]
# 46 Text feature [performed] present in test data point [True]
# 47 Text feature [four] present in test data point [True]
# 49 Text feature [well] present in test data point [True]
# 52 Text feature [gene] present in test data point [True]
# 55 Text feature [including] present in test data point [True]
# 57 Text feature [15] present in test data point [True]
# 58 Text feature [present] present in test data point [True]
# 59 Text feature [sequence] present in test data point [True]
# 60 Text feature [proteins] present in test data point [True]
# 61 Text feature [many] present in test data point [True]
# 62 Text feature [likely] present in test data point [True]
# 64 Text feature [large] present in test data point [True]
# 65 Text feature [additional] present in test data point [True]
# 66 Text feature [identified] present in test data point [True]
# 67 Text feature [involved] present in test data point [True]
# 69 Text feature [expression] present in test data point [True]
# 71 Text feature [suggest] present in test data point [True]
# 72 Text feature [observed] present in test data point [True]
# 73 Text feature [described] present in test data point [True]
# 74 Text feature [previously] present in test data point [True]
# 75 Text feature [mutations] present in test data point [True]
# 76 Text feature [mutation] present in test data point [True]
# 77 Text feature [10] present in test data point [True]
# 78 Text feature [conserved] present in test data point [True]
# 79 Text feature [based] present in test data point [True]
# 80 Text feature [cancer] present in test data point [True]
# 81 Text feature [example] present in test data point [True]
# 82 Text feature [different] present in test data point [True]
# 84 Text feature [multiple] present in test data point [True]
# 85 Text feature [data] present in test data point [True]
# 86 Text feature [addition] present in test data point [True]
# 89 Text feature [first] present in test data point [True]
# 90 Text feature [whereas] present in test data point [True]
# 96 Text feature [could] present in test data point [True]
# 97 Text feature [majority] present in test data point [True]
# Out of the top  100  features  59 are present in query point

# %% [markdown]
# <h2>2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1218530711268841
# for alpha = 11
# Log Loss : 1.1291328099853244
# for alpha = 15
# Log Loss : 1.1430121496436683
# for alpha = 21
# Log Loss : 1.160509738286044
# for alpha = 31
# Log Loss : 1.191288197069033
# for alpha = 41
# Log Loss : 1.2211822655417366
# for alpha = 51
# Log Loss : 1.2349595037415657
# for alpha = 99
# Log Loss : 1.2790282997081295
# For values of best alpha =  5 The train log loss is: 0.9588278190456788
# For values of best alpha =  5 The cross validation log loss is: 1.1218530711268841
# For values of best alpha =  5 The test log loss is: 1.210221149557822

# %% [markdown]
# <h3>2.2. Testing the model with best hyper paramters</h3>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 1.1218530711268841
# Number of mis-classified points : 0.37781954887218044
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

test_point_index = 4
predicted_cls = sig_clf.predict(test_x_tfidf[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_tfidf[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# The  5  nearest neighbours of the test points belongs to classes [2 7 7 7 7]
# Fequency of nearest points : Counter({7: 4, 2: 1})

# %% [markdown]
# <h3>2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

test_point_index = 1

predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_tfidf[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 2
# Actual Class : 4
# the k value for knn is 5 and the nearest neighbours of the test points belongs to classes [2 2 2 1 4]
# Fequency of nearest points : Counter({2: 3, 1: 1, 4: 1})

# %% [markdown]
# <h2>3. Logistic Regression</h2>

# %% [markdown]
# <h3>3.1. With Class balancing</h3>

# %% [markdown]
# <h4>3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1474062125446949
# for alpha = 1e-05
# Log Loss : 1.0690661434383506
# for alpha = 0.0001
# Log Loss : 0.9623394243840163
# for alpha = 0.001
# Log Loss : 0.9898120644182794
# for alpha = 0.01
# Log Loss : 1.1787157742202072
# for alpha = 0.1
# Log Loss : 1.6238766218425515
# for alpha = 1
# Log Loss : 1.7749067481592709
# for alpha = 10
# Log Loss : 1.7910400750461561
# for alpha = 100
# Log Loss : 1.7927901909086534
# For values of best alpha =  0.0001 The train log loss is: 0.604121808650102
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9623394243840163
# For values of best alpha =  0.0001 The test log loss is: 1.0184575628853234

# %% [markdown]
# <h4>3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 0.9623394243840163
# Number of mis-classified points : 0.3308270676691729
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 8
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.144  0.0239 0.0147 0.6413 0.0324 0.0171 0.1148 0.005  0.0068]]
# Actual Class : 4
# --------------------------------------------------
# 46 Text feature [caused] present in test data point [True]
# 95 Text feature [representative] present in test data point [True]
# 108 Text feature [transfected] present in test data point [True]
# 113 Text feature [tagged] present in test data point [True]
# 122 Text feature [show] present in test data point [True]
# 127 Text feature [western] present in test data point [True]
# 130 Text feature [washed] present in test data point [True]
# 136 Text feature [suggesting] present in test data point [True]
# 142 Text feature [protein] present in test data point [True]
# 166 Text feature [suggest] present in test data point [True]
# 170 Text feature [substrate] present in test data point [True]
# 180 Text feature [represent] present in test data point [True]
# 181 Text feature [day] present in test data point [True]
# 197 Text feature [vs] present in test data point [True]
# 201 Text feature [endogenous] present in test data point [True]
# 203 Text feature [high] present in test data point [True]
# 212 Text feature [intermediate] present in test data point [True]
# 216 Text feature [correlation] present in test data point [True]
# 217 Text feature [specifically] present in test data point [True]
# 219 Text feature [catalytic] present in test data point [True]
# 232 Text feature [changes] present in test data point [True]
# 233 Text feature [control] present in test data point [True]
# 234 Text feature [deletion] present in test data point [True]
# 236 Text feature [40] present in test data point [True]
# 239 Text feature [presented] present in test data point [True]
# 245 Text feature [several] present in test data point [True]
# 253 Text feature [particular] present in test data point [True]
# 262 Text feature [bind] present in test data point [True]
# 263 Text feature [na] present in test data point [True]
# 278 Text feature [affected] present in test data point [True]
# 279 Text feature [encoding] present in test data point [True]
# 283 Text feature [therefore] present in test data point [True]
# 288 Text feature [nature] present in test data point [True]
# 291 Text feature [sds] present in test data point [True]
# 303 Text feature [38] present in test data point [True]
# 304 Text feature [low] present in test data point [True]
# 308 Text feature [plates] present in test data point [True]
# 319 Text feature [leads] present in test data point [True]
# 320 Text feature [detected] present in test data point [True]
# 328 Text feature [3b] present in test data point [True]
# 332 Text feature [primary] present in test data point [True]
# 333 Text feature [mechanisms] present in test data point [True]
# 335 Text feature [early] present in test data point [True]
# 336 Text feature [described] present in test data point [True]
# 337 Text feature [hours] present in test data point [True]
# 340 Text feature [44] present in test data point [True]
# 343 Text feature [experiments] present in test data point [True]
# 347 Text feature [acid] present in test data point [True]
# 349 Text feature [resulting] present in test data point [True]
# 350 Text feature [function] present in test data point [True]
# 356 Text feature [anti] present in test data point [True]
# 359 Text feature [characterized] present in test data point [True]
# 360 Text feature [mm] present in test data point [True]
# 366 Text feature [bp] present in test data point [True]
# 371 Text feature [according] present in test data point [True]
# 374 Text feature [reduced] present in test data point [True]
# 376 Text feature [manufacturer] present in test data point [True]
# 378 Text feature [buffer] present in test data point [True]
# 380 Text feature [activity] present in test data point [True]
# 381 Text feature [transfection] present in test data point [True]
# 387 Text feature [amino] present in test data point [True]
# 389 Text feature [involved] present in test data point [True]
# 391 Text feature [dna] present in test data point [True]
# 400 Text feature [following] present in test data point [True]
# 403 Text feature [differences] present in test data point [True]
# 404 Text feature [assays] present in test data point [True]
# 408 Text feature [37] present in test data point [True]
# 409 Text feature [change] present in test data point [True]
# 412 Text feature [proteins] present in test data point [True]
# 415 Text feature [plasmid] present in test data point [True]
# 418 Text feature [times] present in test data point [True]
# 422 Text feature [mutants] present in test data point [True]
# 429 Text feature [culture] present in test data point [True]
# 432 Text feature [min] present in test data point [True]
# 433 Text feature [key] present in test data point [True]
# 436 Text feature [antibody] present in test data point [True]
# 439 Text feature [length] present in test data point [True]
# 440 Text feature [displayed] present in test data point [True]
# 443 Text feature [seen] present in test data point [True]
# 447 Text feature [incubated] present in test data point [True]
# 448 Text feature [assay] present in test data point [True]
# 452 Text feature [generated] present in test data point [True]
# 454 Text feature [leukemia] present in test data point [True]
# 456 Text feature [tested] present in test data point [True]
# 458 Text feature [hypothesis] present in test data point [True]
# 459 Text feature [able] present in test data point [True]
# 463 Text feature [elevated] present in test data point [True]
# 464 Text feature [role] present in test data point [True]
# 471 Text feature [29] present in test data point [True]
# 472 Text feature [wt] present in test data point [True]
# 474 Text feature [45] present in test data point [True]
# 475 Text feature [levels] present in test data point [True]
# 477 Text feature [directly] present in test data point [True]
# 479 Text feature [induced] present in test data point [True]
# 489 Text feature [strong] present in test data point [True]
# 499 Text feature [cells] present in test data point [True]
# Out of the top  500  features  96 are present in query point

# %%
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[4.617e-01 2.322e-01 2.500e-03 2.426e-01 1.970e-02 8.500e-03 2.980e-02
#   2.800e-03 3.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 78 Text feature [box] present in test data point [True]
# 100 Text feature [screening] present in test data point [True]
# 102 Text feature [families] present in test data point [True]
# 107 Text feature [somatic] present in test data point [True]
# 177 Text feature [nuclear] present in test data point [True]
# 178 Text feature [loss] present in test data point [True]
# 180 Text feature [mean] present in test data point [True]
# 183 Text feature [conserved] present in test data point [True]
# 185 Text feature [possible] present in test data point [True]
# 188 Text feature [score] present in test data point [True]
# 202 Text feature [function] present in test data point [True]
# 211 Text feature [context] present in test data point [True]
# 212 Text feature [one] present in test data point [True]
# 214 Text feature [blood] present in test data point [True]
# 218 Text feature [additional] present in test data point [True]
# 224 Text feature [http] present in test data point [True]
# 230 Text feature [biological] present in test data point [True]
# 232 Text feature [large] present in test data point [True]
# 238 Text feature [regions] present in test data point [True]
# 241 Text feature [epithelial] present in test data point [True]
# 249 Text feature [diagnosis] present in test data point [True]
# 250 Text feature [range] present in test data point [True]
# 254 Text feature [many] present in test data point [True]
# 255 Text feature [s1] present in test data point [True]
# 256 Text feature [deletion] present in test data point [True]
# 259 Text feature [present] present in test data point [True]
# 261 Text feature [years] present in test data point [True]
# 267 Text feature [1997] present in test data point [True]
# 268 Text feature [new] present in test data point [True]
# 269 Text feature [whole] present in test data point [True]
# 272 Text feature [spectrum] present in test data point [True]
# 279 Text feature [types] present in test data point [True]
# 281 Text feature [therefore] present in test data point [True]
# 283 Text feature [sequenced] present in test data point [True]
# 285 Text feature [death] present in test data point [True]
# 289 Text feature [cancers] present in test data point [True]
# 290 Text feature [type] present in test data point [True]
# 291 Text feature [ref] present in test data point [True]
# 294 Text feature [allele] present in test data point [True]
# 296 Text feature [heterozygous] present in test data point [True]
# 297 Text feature [coding] present in test data point [True]
# 302 Text feature [view] present in test data point [True]
# 303 Text feature [revealed] present in test data point [True]
# 311 Text feature [general] present in test data point [True]
# 312 Text feature [length] present in test data point [True]
# 315 Text feature [cellular] present in test data point [True]
# 316 Text feature [corresponding] present in test data point [True]
# 318 Text feature [six] present in test data point [True]
# 323 Text feature [provided] present in test data point [True]
# 325 Text feature [sequencing] present in test data point [True]
# 329 Text feature [multiple] present in test data point [True]
# 332 Text feature [tumour] present in test data point [True]
# 333 Text feature [located] present in test data point [True]
# 334 Text feature [42] present in test data point [True]
# 335 Text feature [primers] present in test data point [True]
# 337 Text feature [30] present in test data point [True]
# 341 Text feature [carcinoma] present in test data point [True]
# 342 Text feature [age] present in test data point [True]
# 343 Text feature [powerpoint] present in test data point [True]
# 347 Text feature [staining] present in test data point [True]
# 348 Text feature [least] present in test data point [True]
# 349 Text feature [line] present in test data point [True]
# 351 Text feature [subunit] present in test data point [True]
# 352 Text feature [possibility] present in test data point [True]
# 355 Text feature [based] present in test data point [True]
# 356 Text feature [testing] present in test data point [True]
# 358 Text feature [development] present in test data point [True]
# 360 Text feature [negative] present in test data point [True]
# 361 Text feature [dna] present in test data point [True]
# 366 Text feature [another] present in test data point [True]
# 367 Text feature [common] present in test data point [True]
# 371 Text feature [17] present in test data point [True]
# 373 Text feature [non] present in test data point [True]
# 380 Text feature [remains] present in test data point [True]
# 382 Text feature [either] present in test data point [True]
# 387 Text feature [frequency] present in test data point [True]
# 388 Text feature [exon] present in test data point [True]
# 389 Text feature [germline] present in test data point [True]
# 390 Text feature [carrying] present in test data point [True]
# 391 Text feature [wild] present in test data point [True]
# 396 Text feature [furthermore] present in test data point [True]
# 400 Text feature [eight] present in test data point [True]
# 402 Text feature [samples] present in test data point [True]
# 405 Text feature [performed] present in test data point [True]
# 407 Text feature [carcinomas] present in test data point [True]
# 411 Text feature [recently] present in test data point [True]
# 417 Text feature [sequences] present in test data point [True]
# 418 Text feature [novel] present in test data point [True]
# 427 Text feature [available] present in test data point [True]
# 430 Text feature [majority] present in test data point [True]
# 431 Text feature [mutation] present in test data point [True]
# 435 Text feature [made] present in test data point [True]
# 438 Text feature [even] present in test data point [True]
# 443 Text feature [download] present in test data point [True]
# 445 Text feature [among] present in test data point [True]
# 447 Text feature [sporadic] present in test data point [True]
# 450 Text feature [role] present in test data point [True]
# 452 Text feature [full] present in test data point [True]
# 456 Text feature [showing] present in test data point [True]
# 465 Text feature [codon] present in test data point [True]
# 471 Text feature [binding] present in test data point [True]
# 480 Text feature [pathogenic] present in test data point [True]
# 483 Text feature [proteins] present in test data point [True]
# 489 Text feature [specific] present in test data point [True]
# 490 Text feature [confirmed] present in test data point [True]
# 493 Text feature [see] present in test data point [True]
# 495 Text feature [example] present in test data point [True]
# 496 Text feature [melanoma] present in test data point [True]
# 498 Text feature [cell] present in test data point [True]
# 499 Text feature [identified] present in test data point [True]
# Out of the top  500  features  110 are present in query point

# %% [markdown]
# <h3>3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1185622993430897
# for alpha = 1e-05
# Log Loss : 1.0838350509160155
# for alpha = 0.0001
# Log Loss : 0.9965225624814286
# for alpha = 0.001
# Log Loss : 1.08849422889802
# for alpha = 0.01
# Log Loss : 1.4674147116969465
# for alpha = 0.1
# Log Loss : 1.7468943424259336
# for alpha = 1
# Log Loss : 1.8051635975225717
# For values of best alpha =  0.0001 The train log loss is: 0.5936490538909008
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9965225624814286
# For values of best alpha =  0.0001 The test log loss is: 1.0508393306431671

# %% [markdown]
# <h4>3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 0.9965225624814286
# Number of mis-classified points : 0.33458646616541354
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 8
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1303 0.0237 0.0112 0.6666 0.0296 0.0161 0.1138 0.0039 0.0048]]
# Actual Class : 4
# --------------------------------------------------
# 50 Text feature [caused] present in test data point [True]
# 93 Text feature [show] present in test data point [True]
# 95 Text feature [tagged] present in test data point [True]
# 100 Text feature [western] present in test data point [True]
# 119 Text feature [protein] present in test data point [True]
# 120 Text feature [transfected] present in test data point [True]
# 121 Text feature [suggest] present in test data point [True]
# 125 Text feature [suggesting] present in test data point [True]
# 131 Text feature [washed] present in test data point [True]
# 132 Text feature [endogenous] present in test data point [True]
# 136 Text feature [representative] present in test data point [True]
# 143 Text feature [correlation] present in test data point [True]
# 152 Text feature [high] present in test data point [True]
# 156 Text feature [control] present in test data point [True]
# 162 Text feature [represent] present in test data point [True]
# 169 Text feature [bind] present in test data point [True]
# 170 Text feature [specifically] present in test data point [True]
# 174 Text feature [intermediate] present in test data point [True]
# 179 Text feature [day] present in test data point [True]
# 187 Text feature [vs] present in test data point [True]
# 194 Text feature [substrate] present in test data point [True]
# 208 Text feature [several] present in test data point [True]
# 217 Text feature [catalytic] present in test data point [True]
# 232 Text feature [40] present in test data point [True]
# 247 Text feature [deletion] present in test data point [True]
# 249 Text feature [particular] present in test data point [True]
# 250 Text feature [low] present in test data point [True]
# 253 Text feature [presented] present in test data point [True]
# 255 Text feature [changes] present in test data point [True]
# 267 Text feature [therefore] present in test data point [True]
# 279 Text feature [38] present in test data point [True]
# 286 Text feature [sds] present in test data point [True]
# 288 Text feature [na] present in test data point [True]
# 292 Text feature [leads] present in test data point [True]
# 294 Text feature [affected] present in test data point [True]
# 296 Text feature [described] present in test data point [True]
# 298 Text feature [detected] present in test data point [True]
# 301 Text feature [3b] present in test data point [True]
# 303 Text feature [encoding] present in test data point [True]
# 311 Text feature [44] present in test data point [True]
# 315 Text feature [characterized] present in test data point [True]
# 320 Text feature [nature] present in test data point [True]
# 323 Text feature [hours] present in test data point [True]
# 324 Text feature [plates] present in test data point [True]
# 326 Text feature [differences] present in test data point [True]
# 328 Text feature [acid] present in test data point [True]
# 334 Text feature [anti] present in test data point [True]
# 337 Text feature [resulting] present in test data point [True]
# 341 Text feature [primary] present in test data point [True]
# 342 Text feature [function] present in test data point [True]
# 343 Text feature [tested] present in test data point [True]
# 345 Text feature [mechanisms] present in test data point [True]
# 346 Text feature [manufacturer] present in test data point [True]
# 354 Text feature [early] present in test data point [True]
# 356 Text feature [experiments] present in test data point [True]
# 357 Text feature [transfection] present in test data point [True]
# 359 Text feature [amino] present in test data point [True]
# 363 Text feature [displayed] present in test data point [True]
# 366 Text feature [according] present in test data point [True]
# 369 Text feature [bp] present in test data point [True]
# 370 Text feature [dna] present in test data point [True]
# 373 Text feature [plasmid] present in test data point [True]
# 378 Text feature [activity] present in test data point [True]
# 384 Text feature [assays] present in test data point [True]
# 385 Text feature [hypothesis] present in test data point [True]
# 389 Text feature [length] present in test data point [True]
# 394 Text feature [leukemia] present in test data point [True]
# 398 Text feature [generated] present in test data point [True]
# 403 Text feature [assay] present in test data point [True]
# 404 Text feature [following] present in test data point [True]
# 405 Text feature [antibody] present in test data point [True]
# 409 Text feature [role] present in test data point [True]
# 414 Text feature [reduced] present in test data point [True]
# 423 Text feature [elevated] present in test data point [True]
# 424 Text feature [culture] present in test data point [True]
# 425 Text feature [key] present in test data point [True]
# 430 Text feature [change] present in test data point [True]
# 431 Text feature [able] present in test data point [True]
# 433 Text feature [directly] present in test data point [True]
# 436 Text feature [seen] present in test data point [True]
# 438 Text feature [rates] present in test data point [True]
# 439 Text feature [proteins] present in test data point [True]
# 440 Text feature [induced] present in test data point [True]
# 442 Text feature [37] present in test data point [True]
# 447 Text feature [buffer] present in test data point [True]
# 454 Text feature [significantly] present in test data point [True]
# 455 Text feature [29] present in test data point [True]
# 457 Text feature [levels] present in test data point [True]
# 459 Text feature [45] present in test data point [True]
# 462 Text feature [treated] present in test data point [True]
# 464 Text feature [mutants] present in test data point [True]
# 470 Text feature [times] present in test data point [True]
# 473 Text feature [incubated] present in test data point [True]
# 478 Text feature [involved] present in test data point [True]
# 483 Text feature [mutagenesis] present in test data point [True]
# 485 Text feature [32] present in test data point [True]
# 487 Text feature [cells] present in test data point [True]
# 495 Text feature [mm] present in test data point [True]
# 497 Text feature [min] present in test data point [True]
# Out of the top  500  features  99 are present in query point

# %% [markdown]
# <h4>3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[4.765e-01 2.281e-01 1.400e-03 2.390e-01 1.650e-02 7.800e-03 3.010e-02
#   5.000e-04 2.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 65 Text feature [box] present in test data point [True]
# 84 Text feature [screening] present in test data point [True]
# 98 Text feature [families] present in test data point [True]
# 102 Text feature [somatic] present in test data point [True]
# 167 Text feature [loss] present in test data point [True]
# 170 Text feature [conserved] present in test data point [True]
# 174 Text feature [possible] present in test data point [True]
# 175 Text feature [mean] present in test data point [True]
# 182 Text feature [nuclear] present in test data point [True]
# 193 Text feature [score] present in test data point [True]
# 194 Text feature [function] present in test data point [True]
# 197 Text feature [context] present in test data point [True]
# 214 Text feature [additional] present in test data point [True]
# 219 Text feature [large] present in test data point [True]
# 221 Text feature [epithelial] present in test data point [True]
# 222 Text feature [biological] present in test data point [True]
# 223 Text feature [one] present in test data point [True]
# 227 Text feature [blood] present in test data point [True]
# 232 Text feature [http] present in test data point [True]
# 234 Text feature [regions] present in test data point [True]
# 235 Text feature [present] present in test data point [True]
# 236 Text feature [range] present in test data point [True]
# 242 Text feature [many] present in test data point [True]
# 244 Text feature [new] present in test data point [True]
# 246 Text feature [s1] present in test data point [True]
# 250 Text feature [1997] present in test data point [True]
# 252 Text feature [diagnosis] present in test data point [True]
# 256 Text feature [whole] present in test data point [True]
# 257 Text feature [deletion] present in test data point [True]
# 268 Text feature [years] present in test data point [True]
# 275 Text feature [types] present in test data point [True]
# 278 Text feature [spectrum] present in test data point [True]
# 286 Text feature [type] present in test data point [True]
# 287 Text feature [view] present in test data point [True]
# 288 Text feature [42] present in test data point [True]
# 289 Text feature [therefore] present in test data point [True]
# 290 Text feature [death] present in test data point [True]
# 292 Text feature [allele] present in test data point [True]
# 295 Text feature [multiple] present in test data point [True]
# 296 Text feature [cellular] present in test data point [True]
# 300 Text feature [revealed] present in test data point [True]
# 301 Text feature [cancers] present in test data point [True]
# 302 Text feature [tumour] present in test data point [True]
# 304 Text feature [ref] present in test data point [True]
# 308 Text feature [general] present in test data point [True]
# 318 Text feature [length] present in test data point [True]
# 320 Text feature [development] present in test data point [True]
# 322 Text feature [common] present in test data point [True]
# 323 Text feature [provided] present in test data point [True]
# 324 Text feature [coding] present in test data point [True]
# 325 Text feature [corresponding] present in test data point [True]
# 326 Text feature [powerpoint] present in test data point [True]
# 327 Text feature [line] present in test data point [True]
# 328 Text feature [carcinoma] present in test data point [True]
# 331 Text feature [sequenced] present in test data point [True]
# 333 Text feature [testing] present in test data point [True]
# 335 Text feature [another] present in test data point [True]
# 337 Text feature [heterozygous] present in test data point [True]
# 341 Text feature [staining] present in test data point [True]
# 343 Text feature [least] present in test data point [True]
# 346 Text feature [six] present in test data point [True]
# 347 Text feature [possibility] present in test data point [True]
# 349 Text feature [located] present in test data point [True]
# 353 Text feature [sequencing] present in test data point [True]
# 356 Text feature [non] present in test data point [True]
# 358 Text feature [30] present in test data point [True]
# 363 Text feature [based] present in test data point [True]
# 364 Text feature [either] present in test data point [True]
# 366 Text feature [negative] present in test data point [True]
# 372 Text feature [wild] present in test data point [True]
# 377 Text feature [age] present in test data point [True]
# 379 Text feature [17] present in test data point [True]
# 382 Text feature [primers] present in test data point [True]
# 383 Text feature [showing] present in test data point [True]
# 384 Text feature [carcinomas] present in test data point [True]
# 388 Text feature [frequency] present in test data point [True]
# 390 Text feature [dna] present in test data point [True]
# 393 Text feature [subunit] present in test data point [True]
# 395 Text feature [even] present in test data point [True]
# 398 Text feature [recently] present in test data point [True]
# 400 Text feature [furthermore] present in test data point [True]
# 401 Text feature [majority] present in test data point [True]
# 405 Text feature [germline] present in test data point [True]
# 406 Text feature [samples] present in test data point [True]
# 415 Text feature [codon] present in test data point [True]
# 416 Text feature [download] present in test data point [True]
# 418 Text feature [remains] present in test data point [True]
# 421 Text feature [eight] present in test data point [True]
# 424 Text feature [among] present in test data point [True]
# 425 Text feature [available] present in test data point [True]
# 428 Text feature [performed] present in test data point [True]
# 432 Text feature [made] present in test data point [True]
# 435 Text feature [carrying] present in test data point [True]
# 438 Text feature [exon] present in test data point [True]
# 440 Text feature [mutation] present in test data point [True]
# 441 Text feature [novel] present in test data point [True]
# 443 Text feature [melanoma] present in test data point [True]
# 446 Text feature [sporadic] present in test data point [True]
# 453 Text feature [pathogenic] present in test data point [True]
# 455 Text feature [full] present in test data point [True]
# 460 Text feature [confirmed] present in test data point [True]
# 462 Text feature [sequences] present in test data point [True]
# 474 Text feature [indeed] present in test data point [True]
# 475 Text feature [cell] present in test data point [True]
# 476 Text feature [role] present in test data point [True]
# 477 Text feature [specific] present in test data point [True]
# 479 Text feature [binding] present in test data point [True]
# 480 Text feature [36] present in test data point [True]
# 487 Text feature [proteins] present in test data point [True]
# 493 Text feature [example] present in test data point [True]
# 494 Text feature [current] present in test data point [True]
# 495 Text feature [identified] present in test data point [True]
# Out of the top  500  features  112 are present in query point

# %% [markdown]
# <h2>4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.102624997661859
# for C = 0.0001
# Log Loss : 1.049881051233513
# for C = 0.001
# Log Loss : 1.0434456957901814
# for C = 0.01
# Log Loss : 1.3149721647533854
# for C = 0.1
# Log Loss : 1.6379102699408634
# for C = 1
# Log Loss : 1.7932131080070652
# for C = 10
# Log Loss : 1.793213043382928
# for C = 100
# Log Loss : 1.793212989455238
# For values of best alpha =  0.001 The train log loss is: 0.8002386607701021
# For values of best alpha =  0.001 The cross validation log loss is: 1.0434456957901814
# For values of best alpha =  0.001 The test log loss is: 1.1334212613403778

# %% [markdown]
# <h3>4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_tfidf, train_y,cv_x_tfidf,cv_y, clf)
# Out:
# Log loss : 1.0434456957901814
# Number of mis-classified points : 0.33270676691729323
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 8
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1024 0.0678 0.021  0.4545 0.0592 0.0395 0.2456 0.0053 0.0047]]
# Actual Class : 4
# --------------------------------------------------
# 26 Text feature [caused] present in test data point [True]
# 27 Text feature [suggesting] present in test data point [True]
# 33 Text feature [show] present in test data point [True]
# 34 Text feature [substrate] present in test data point [True]
# 37 Text feature [transfected] present in test data point [True]
# 161 Text feature [day] present in test data point [True]
# 163 Text feature [catalytic] present in test data point [True]
# 165 Text feature [presented] present in test data point [True]
# 166 Text feature [representative] present in test data point [True]
# 171 Text feature [encoding] present in test data point [True]
# 172 Text feature [tagged] present in test data point [True]
# 210 Text feature [particular] present in test data point [True]
# 211 Text feature [western] present in test data point [True]
# 213 Text feature [washed] present in test data point [True]
# 215 Text feature [several] present in test data point [True]
# 218 Text feature [40] present in test data point [True]
# 219 Text feature [na] present in test data point [True]
# 224 Text feature [high] present in test data point [True]
# 225 Text feature [mutants] present in test data point [True]
# 228 Text feature [changes] present in test data point [True]
# 229 Text feature [protein] present in test data point [True]
# 232 Text feature [mechanisms] present in test data point [True]
# 236 Text feature [suggest] present in test data point [True]
# 237 Text feature [hours] present in test data point [True]
# 239 Text feature [represent] present in test data point [True]
# 240 Text feature [38] present in test data point [True]
# 241 Text feature [sds] present in test data point [True]
# 243 Text feature [intermediate] present in test data point [True]
# 244 Text feature [involved] present in test data point [True]
# 268 Text feature [primary] present in test data point [True]
# 270 Text feature [control] present in test data point [True]
# 272 Text feature [deletion] present in test data point [True]
# 282 Text feature [plates] present in test data point [True]
# 283 Text feature [complex] present in test data point [True]
# 284 Text feature [mm] present in test data point [True]
# 287 Text feature [therefore] present in test data point [True]
# 292 Text feature [acid] present in test data point [True]
# 294 Text feature [mutagenesis] present in test data point [True]
# 296 Text feature [nature] present in test data point [True]
# 297 Text feature [specifically] present in test data point [True]
# 304 Text feature [amino] present in test data point [True]
# 306 Text feature [correlation] present in test data point [True]
# 307 Text feature [vs] present in test data point [True]
# 309 Text feature [detected] present in test data point [True]
# 310 Text feature [buffer] present in test data point [True]
# 313 Text feature [change] present in test data point [True]
# 315 Text feature [characterized] present in test data point [True]
# 318 Text feature [endogenous] present in test data point [True]
# 319 Text feature [resulting] present in test data point [True]
# 323 Text feature [directly] present in test data point [True]
# 324 Text feature [key] present in test data point [True]
# 326 Text feature [44] present in test data point [True]
# 356 Text feature [early] present in test data point [True]
# 357 Text feature [able] present in test data point [True]
# 358 Text feature [affected] present in test data point [True]
# 359 Text feature [culture] present in test data point [True]
# 360 Text feature [strong] present in test data point [True]
# 363 Text feature [demonstrate] present in test data point [True]
# 366 Text feature [activity] present in test data point [True]
# 367 Text feature [still] present in test data point [True]
# 368 Text feature [experiments] present in test data point [True]
# 372 Text feature [anti] present in test data point [True]
# 375 Text feature [proteins] present in test data point [True]
# 376 Text feature [leads] present in test data point [True]
# 377 Text feature [generated] present in test data point [True]
# 381 Text feature [incubated] present in test data point [True]
# 385 Text feature [following] present in test data point [True]
# 388 Text feature [bind] present in test data point [True]
# 389 Text feature [tested] present in test data point [True]
# 390 Text feature [s3] present in test data point [True]
# 392 Text feature [described] present in test data point [True]
# 394 Text feature [times] present in test data point [True]
# 396 Text feature [seen] present in test data point [True]
# 400 Text feature [assays] present in test data point [True]
# 402 Text feature [according] present in test data point [True]
# 404 Text feature [cells] present in test data point [True]
# 405 Text feature [3b] present in test data point [True]
# 407 Text feature [wt] present in test data point [True]
# 409 Text feature [flag] present in test data point [True]
# 416 Text feature [transfection] present in test data point [True]
# 417 Text feature [reduced] present in test data point [True]
# 420 Text feature [function] present in test data point [True]
# 422 Text feature [low] present in test data point [True]
# 423 Text feature [induced] present in test data point [True]
# 425 Text feature [indeed] present in test data point [True]
# 432 Text feature [respectively] present in test data point [True]
# 436 Text feature [37] present in test data point [True]
# 437 Text feature [shown] present in test data point [True]
# 444 Text feature [presence] present in test data point [True]
# 449 Text feature [p85] present in test data point [True]
# 450 Text feature [fig] present in test data point [True]
# 454 Text feature [enhanced] present in test data point [True]
# 455 Text feature [elevated] present in test data point [True]
# 456 Text feature [structural] present in test data point [True]
# 457 Text feature [antibody] present in test data point [True]
# 462 Text feature [plasmid] present in test data point [True]
# 463 Text feature [dna] present in test data point [True]
# 464 Text feature [page] present in test data point [True]
# Out of the top  500  features  98 are present in query point

# %%
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.3602 0.2183 0.008  0.2939 0.0257 0.0231 0.0675 0.0029 0.0004]]
# Actual Class : 4
# --------------------------------------------------
# 135 Text feature [somatic] present in test data point [True]
# 136 Text feature [screening] present in test data point [True]
# 169 Text feature [score] present in test data point [True]
# 174 Text feature [subunit] present in test data point [True]
# 177 Text feature [s1] present in test data point [True]
# 180 Text feature [box] present in test data point [True]
# 200 Text feature [families] present in test data point [True]
# 203 Text feature [possible] present in test data point [True]
# 209 Text feature [biological] present in test data point [True]
# 211 Text feature [epithelial] present in test data point [True]
# 216 Text feature [additional] present in test data point [True]
# 217 Text feature [primers] present in test data point [True]
# 218 Text feature [mean] present in test data point [True]
# 222 Text feature [length] present in test data point [True]
# 227 Text feature [death] present in test data point [True]
# 230 Text feature [six] present in test data point [True]
# 231 Text feature [conserved] present in test data point [True]
# 235 Text feature [exon] present in test data point [True]
# 236 Text feature [loss] present in test data point [True]
# 241 Text feature [carcinoma] present in test data point [True]
# 242 Text feature [sequenced] present in test data point [True]
# 244 Text feature [revealed] present in test data point [True]
# 245 Text feature [one] present in test data point [True]
# 248 Text feature [cancers] present in test data point [True]
# 251 Text feature [http] present in test data point [True]
# 253 Text feature [heterozygous] present in test data point [True]
# 272 Text feature [blood] present in test data point [True]
# 273 Text feature [new] present in test data point [True]
# 274 Text feature [cellular] present in test data point [True]
# 276 Text feature [years] present in test data point [True]
# 279 Text feature [sequencing] present in test data point [True]
# 280 Text feature [remains] present in test data point [True]
# 281 Text feature [located] present in test data point [True]
# 285 Text feature [line] present in test data point [True]
# 286 Text feature [17] present in test data point [True]
# 287 Text feature [type] present in test data point [True]
# 290 Text feature [range] present in test data point [True]
# 294 Text feature [diagnosis] present in test data point [True]
# 296 Text feature [tumour] present in test data point [True]
# 298 Text feature [many] present in test data point [True]
# 299 Text feature [deletion] present in test data point [True]
# 300 Text feature [ref] present in test data point [True]
# 303 Text feature [cell] present in test data point [True]
# 304 Text feature [30] present in test data point [True]
# 305 Text feature [binding] present in test data point [True]
# 306 Text feature [large] present in test data point [True]
# 307 Text feature [therefore] present in test data point [True]
# 311 Text feature [provided] present in test data point [True]
# 312 Text feature [non] present in test data point [True]
# 314 Text feature [nuclear] present in test data point [True]
# 325 Text feature [negative] present in test data point [True]
# 329 Text feature [whole] present in test data point [True]
# 330 Text feature [full] present in test data point [True]
# 331 Text feature [showing] present in test data point [True]
# 332 Text feature [types] present in test data point [True]
# 334 Text feature [1997] present in test data point [True]
# 336 Text feature [allele] present in test data point [True]
# 340 Text feature [regions] present in test data point [True]
# 342 Text feature [multiple] present in test data point [True]
# 351 Text feature [spectrum] present in test data point [True]
# 353 Text feature [sporadic] present in test data point [True]
# 354 Text feature [like] present in test data point [True]
# 355 Text feature [possibility] present in test data point [True]
# 356 Text feature [corresponding] present in test data point [True]
# 357 Text feature [example] present in test data point [True]
# 360 Text feature [function] present in test data point [True]
# 361 Text feature [staining] present in test data point [True]
# 365 Text feature [based] present in test data point [True]
# 368 Text feature [powerpoint] present in test data point [True]
# 371 Text feature [mediated] present in test data point [True]
# 372 Text feature [testing] present in test data point [True]
# 375 Text feature [frequency] present in test data point [True]
# 377 Text feature [carcinomas] present in test data point [True]
# 378 Text feature [performed] present in test data point [True]
# 379 Text feature [supplementary] present in test data point [True]
# 380 Text feature [18] present in test data point [True]
# 388 Text feature [level] present in test data point [True]
# 391 Text feature [another] present in test data point [True]
# 418 Text feature [recently] present in test data point [True]
# 420 Text feature [melanoma] present in test data point [True]
# 424 Text feature [coding] present in test data point [True]
# 425 Text feature [context] present in test data point [True]
# 426 Text feature [36] present in test data point [True]
# 428 Text feature [wild] present in test data point [True]
# 431 Text feature [carrying] present in test data point [True]
# 432 Text feature [key] present in test data point [True]
# 434 Text feature [mutation] present in test data point [True]
# 446 Text feature [development] present in test data point [True]
# 447 Text feature [identified] present in test data point [True]
# 448 Text feature [13] present in test data point [True]
# 450 Text feature [see] present in test data point [True]
# 451 Text feature [general] present in test data point [True]
# 452 Text feature [least] present in test data point [True]
# 455 Text feature [novel] present in test data point [True]
# 456 Text feature [age] present in test data point [True]
# 459 Text feature [proteins] present in test data point [True]
# 463 Text feature [could] present in test data point [True]
# 465 Text feature [made] present in test data point [True]
# 469 Text feature [co] present in test data point [True]
# 470 Text feature [majority] present in test data point [True]
# 473 Text feature [download] present in test data point [True]
# 474 Text feature [confirmed] present in test data point [True]
# 479 Text feature [sequences] present in test data point [True]
# 487 Text feature [observations] present in test data point [True]
# 490 Text feature [exons] present in test data point [True]
# 492 Text feature [atp] present in test data point [True]
# 494 Text feature [furthermore] present in test data point [True]
# 495 Text feature [42] present in test data point [True]
# 496 Text feature [either] present in test data point [True]
# 498 Text feature [results] present in test data point [True]
# 499 Text feature [11] present in test data point [True]
# Out of the top  500  features  111 are present in query point

# %% [markdown]
# <h2>5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>5.1. Hyper paramter tuning</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_tfidf, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_tfidf, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2083454993194485
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2506904329646955
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1911759197417873
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.241755032400395
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.1836402022009278
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2336610789579268
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1802242063670216
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2291265866271421
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1757838246696297
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2267692262997596
# For values of best estimator =  2000 The train log loss is: 0.8606790606268845
# For values of best estimator =  2000 The cross validation log loss is: 1.1757838246696297
# For values of best estimator =  2000 The test log loss is: 1.2025350498504086

# %% [markdown]
# <h3>5.2. Testing model with best hyper parameters </h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y,cv_x_tfidf,cv_y, clf)
# Out:
# Log loss : 1.1757838246696297
# Number of mis-classified points : 0.40789473684210525
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>5.3. Feature Importance</h3>

# %% [markdown]
# <h4>5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

test_point_index = 8
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0586 0.1047 0.0329 0.3153 0.0589 0.0485 0.3669 0.0074 0.0069]]
# Actual Class : 4
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 5 Text feature [function] present in test data point [True]
# 7 Text feature [constitutive] present in test data point [True]
# 8 Text feature [phosphorylation] present in test data point [True]
# 9 Text feature [inhibitors] present in test data point [True]
# 10 Text feature [oncogenic] present in test data point [True]
# 16 Text feature [protein] present in test data point [True]
# 22 Text feature [inhibitor] present in test data point [True]
# 23 Text feature [transforming] present in test data point [True]
# 26 Text feature [cells] present in test data point [True]
# 37 Text feature [growth] present in test data point [True]
# 38 Text feature [expression] present in test data point [True]
# 41 Text feature [signaling] present in test data point [True]
# 46 Text feature [cell] present in test data point [True]
# 49 Text feature [inhibited] present in test data point [True]
# 50 Text feature [treated] present in test data point [True]
# 54 Text feature [proteins] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 56 Text feature [downstream] present in test data point [True]
# 63 Text feature [akt] present in test data point [True]
# 64 Text feature [activate] present in test data point [True]
# 65 Text feature [phospho] present in test data point [True]
# 69 Text feature [expressing] present in test data point [True]
# 70 Text feature [oncogene] present in test data point [True]
# 74 Text feature [proliferation] present in test data point [True]
# 76 Text feature [activity] present in test data point [True]
# 85 Text feature [potential] present in test data point [True]
# 86 Text feature [catalytic] present in test data point [True]
# 87 Text feature [expected] present in test data point [True]
# 88 Text feature [tagged] present in test data point [True]
# 97 Text feature [dna] present in test data point [True]
# Out of the top  100  features  33 are present in query point

# %% [markdown]
# <h4>5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.4033 0.0581 0.0184 0.3097 0.0632 0.0792 0.0444 0.0061 0.0175]]
# Actuall Class : 4
# --------------------------------------------------
# 2 Text feature [activation] present in test data point [True]
# 4 Text feature [suppressor] present in test data point [True]
# 5 Text feature [function] present in test data point [True]
# 11 Text feature [loss] present in test data point [True]
# 13 Text feature [missense] present in test data point [True]
# 16 Text feature [protein] present in test data point [True]
# 18 Text feature [brca1] present in test data point [True]
# 26 Text feature [cells] present in test data point [True]
# 38 Text feature [expression] present in test data point [True]
# 39 Text feature [pathogenic] present in test data point [True]
# 45 Text feature [functional] present in test data point [True]
# 46 Text feature [cell] present in test data point [True]
# 50 Text feature [treated] present in test data point [True]
# 54 Text feature [proteins] present in test data point [True]
# 56 Text feature [downstream] present in test data point [True]
# 59 Text feature [advanced] present in test data point [True]
# 61 Text feature [response] present in test data point [True]
# 66 Text feature [patients] present in test data point [True]
# 70 Text feature [oncogene] present in test data point [True]
# 71 Text feature [nuclear] present in test data point [True]
# 78 Text feature [clinical] present in test data point [True]
# 87 Text feature [expected] present in test data point [True]
# 92 Text feature [arrest] present in test data point [True]
# 94 Text feature [conserved] present in test data point [True]
# 96 Text feature [null] present in test data point [True]
# 97 Text feature [dna] present in test data point [True]
# 98 Text feature [carriers] present in test data point [True]
# Out of the top  100  features  27 are present in query point

# %% [markdown]
# <h2>7 Stack the models </h2>

# %% [markdown]
# <h3>7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_tfidf, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_tfidf, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_tfidf, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_tfidf, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_tfidf))))
sig_clf2.fit(train_x_tfidf, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_tfidf))))
sig_clf3.fit(train_x_tfidf, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_tfidf))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_tfidf, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Support vector machines : Log Loss: 1.79
# Naive Bayes : Log Loss: 1.15
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.037
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.509
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.101
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.115
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.244

# %% [markdown]
# <h3>7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_tfidf, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_tfidf))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_tfidf))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_tfidf))
# Out:
# Log loss (train) on the stacking classifier : 0.8173778564740473
# Log loss (CV) on the stacking classifier : 1.101180213900247
# Log loss (test) on the stacking classifier : 1.1487590324789516
# Number of missclassified point : 0.3954887218045113
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_tfidf, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_tfidf)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_tfidf)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_tfidf)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_tfidf))
# Out:
# Log loss (train) on the VotingClassifier : 0.9627100172646266
# Log loss (CV) on the VotingClassifier : 1.1568563733224675
# Log loss (test) on the VotingClassifier : 1.202798821665402
# Number of missclassified point : 0.39097744360902253
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## observations

# %% [markdown]
# |Model|Train log loss|CV log loss|Test log loss|Misclassification|
# |:---:|:------------:|:---------:|:-----------:|:---------------:|
# |Naive Bayes|0.765|1.153|1.181|36.09%|
# |K-NN       |0.959|1.122|1.210|37.78%|
# |Logistic Regression (class balancing)|0.604|0.962|1.018|33.08%|
# |Logistic Regression (with out calss balancing)|0.593|0.996|1.051|33.45%|
# |Linear SVM|0.800|1.043|1.133|33.27%|
# |Random Forest Classifier|0.860|1.176|1.203|40.78%|
# |Stack the Models|1.101|1.149|0.395|39.5%|
# |Maximum vote classifier|0.962|1.157|1.203|39.09%|

# %% [markdown]
# ### Random model
# CV   log loss:2.472
# Test log loss:2.464

# %% [markdown]
# ##### By observing Logistic Regression and Linear SVM are performing better
